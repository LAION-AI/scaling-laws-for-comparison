# %%
import os
import pandas as pd
from IPython.display import display, display_html
import numpy as np
import matplotlib.pyplot as plt
def samples_seen_from_str(samples):
    if samples.endswith("M"):
        samples = float(samples[:-1]) * 10**6
    elif samples.endswith("B"):
        samples = float(samples[:-1]) * 10**9
    elif samples.endswith("K"):
        samples = float(samples[:-1]) * 10**3
    return samples
def human(v):
    # check closest from `scales`
    dist = np.abs(np.array(scales_numeric) - v)
    if dist.min() < 1e9:
        idx = dist.argmin()
        return scales[idx]
    else:
        if v < 10 ** 6:
            return str(v)
        elif v > 10**6 and v < 10**9:
            return (str(v/10**6)+"M").replace(".0M", "M")
        elif v > 10**9:
            return (str(v/10**9)+"B").replace(".0B", "B")
scales = [
    "1.28M",
    "3M",
    "6.4M",
    "12.8M",
    "30M",
    "64M",
    "128M",
    "300M",
    "640M",
    "1.28B",
    "3B",
]
scales_numeric = [samples_seen_from_str(s) for s in scales]

# %%
df = pd.read_csv("scaling_laws/data/all_results.csv.gz")
df["samples_seen_scale_pretty"] = df.total_samples_seen.apply(lambda s:human(s))
df = df[
    ((df.pretrain_dataset=="datacomp_1b") & (df.lr_scheduler == "cosine")) | 
    ((df.pretrain_dataset=="datacomp_1b") & (df.lr_scheduler == "const")) |
    ((df.pretrain_dataset=="relaion2b-en") & (df.lr_scheduler == "cosine"))
]
model_profile = pd.read_csv("model_profile.csv").set_index("model_simple_namespace")

# %%
evals = [
 ("imagenet1k", "acc1"), # ImageNet-1k zero-shot classification
 ("mscoco_captions", "image_retrieval_recall@5"), # MS-COCO Recall@5 zero-shot image retrieval (T->I)
 ("mscoco_captions", "text_retrieval_recall@5"), # MS-COCO Recall@5 zero-shot text retrieval (I->T)
 ("datacomp_classification", "acc1"), # average over 35 classification tasks from DataComp (Tab.15 from https://arxiv.org/abs/2304.14108)
 ("imagenet_distribution_shift", "acc1"), # average over ImageNet-v2, ImageNet-R, ImageNet-Sketch, ImageNet-A, ObjectNet zero-shot classification
]   
for scheduler in ("cosine", "const",):
    for pretrain_dataset in ("datacomp_1b", "relaion2b-en"):
        for ds, metric in evals:
            for eval_type in ("similarity",):
                d = df.copy()
                d = d[d.eval_type==eval_type]
                d = d[d.pretrain_dataset==pretrain_dataset]
                d = d[d.downstream_dataset==ds]                        
                if scheduler != "const":            
                    d = d[d.epoch==d.total_epochs]
                d = d[d.lr_scheduler==scheduler]
                d = d[d.samples_seen_scale_pretty.isin(scales)]
                vars=("samples_seen_scale_pretty", "model_simple_namespace")
                d = d.sort_values(by=metric, ascending=False)
                d = d.drop_duplicates(subset=vars, keep="first") # Show best result for each model x samples seen
                d = pd.pivot(
                    d,
                    index="samples_seen_scale_pretty",
                    columns=("model_simple_namespace"),
                    values=metric,
                )
                if not len(d):
                    continue
                d.index.name = "Samples Seen"
                
                d.columns.name = "Model"
                cols = d.columns
                cols = sorted(cols, key=lambda k:model_profile.loc[k].gflops)
                d = d[cols]
                d.columns = ["_".join(k.split("_")[::-1]) for k in d.columns]
                missing = [s for s in scales if s not in d.index]
                for s in missing:
                    d.loc[s] = np.nan
                index = sorted(d.index, key=lambda k:samples_seen_from_str(k))
                d = d.loc[index]
                d = d.T
                        
                maxval = np.nanmax(d.values)
                minval = np.nanmin(d.values)
                style = d.style.background_gradient(cmap="viridis", vmin=minval, vmax=maxval, axis=None)                    
                style = style.format(precision=3, na_rep="NA")
                display_html(f"<font color='green'>'{ds}'</font> {metric} results for models pre-trained on <font color='red'>'{pretrain_dataset}'</font>  using scheduler <font color='blue'>'{scheduler}'</font>:", raw=True)            
                display(style)
# Out:
# <font color='green'>'imagenet1k'</font> acc1 results for models pre-trained on <font color='red'>'datacomp_1b'</font>  using scheduler <font color='blue'>'cosine'</font>:
# <style type="text/css">
# #T_f8a0b_row0_col0, #T_f8a0b_row1_col0, #T_f8a0b_row2_col0, #T_f8a0b_row3_col0, #T_f8a0b_row6_col0, #T_f8a0b_row8_col0, #T_f8a0b_row9_col0, #T_f8a0b_row10_col0, #T_f8a0b_row13_col0, #T_f8a0b_row16_col0, #T_f8a0b_row19_col0, #T_f8a0b_row25_col0, #T_f8a0b_row28_col0, #T_f8a0b_row29_col0 {
#   background-color: #440256;
#   color: #f1f1f1;
# }
# #T_f8a0b_row0_col1, #T_f8a0b_row1_col1, #T_f8a0b_row3_col1, #T_f8a0b_row9_col1, #T_f8a0b_row19_col1, #T_f8a0b_row28_col1, #T_f8a0b_row31_col1, #T_f8a0b_row32_col1 {
#   background-color: #460a5d;
#   color: #f1f1f1;
# }
# #T_f8a0b_row0_col2, #T_f8a0b_row3_col2 {
#   background-color: #48186a;
#   color: #f1f1f1;
# }
# #T_f8a0b_row0_col3 {
#   background-color: #472a7a;
#   color: #f1f1f1;
# }
# #T_f8a0b_row0_col4 {
#   background-color: #3e4a89;
#   color: #f1f1f1;
# }
# #T_f8a0b_row0_col5, #T_f8a0b_row23_col4 {
#   background-color: #31688e;
#   color: #f1f1f1;
# }
# #T_f8a0b_row0_col6, #T_f8a0b_row10_col6, #T_f8a0b_row21_col5 {
#   background-color: #26828e;
#   color: #f1f1f1;
# }
# #T_f8a0b_row0_col7, #T_f8a0b_row10_col7 {
#   background-color: #1e9c89;
#   color: #f1f1f1;
# }
# #T_f8a0b_row0_col8, #T_f8a0b_row9_col7 {
#   background-color: #27ad81;
#   color: #f1f1f1;
# }
# #T_f8a0b_row0_col9, #T_f8a0b_row14_col7 {
#   background-color: #35b779;
#   color: #f1f1f1;
# }
# #T_f8a0b_row0_col10, #T_f8a0b_row18_col7 {
#   background-color: #44bf70;
#   color: #f1f1f1;
# }
# #T_f8a0b_row1_col2 {
#   background-color: #481769;
#   color: #f1f1f1;
# }
# #T_f8a0b_row1_col3, #T_f8a0b_row26_col2 {
#   background-color: #482878;
#   color: #f1f1f1;
# }
# #T_f8a0b_row1_col4, #T_f8a0b_row33_col3, #T_f8a0b_row34_col3 {
#   background-color: #3f4788;
#   color: #f1f1f1;
# }
# #T_f8a0b_row1_col5, #T_f8a0b_row14_col4, #T_f8a0b_row22_col4 {
#   background-color: #32658e;
#   color: #f1f1f1;
# }
# #T_f8a0b_row1_col6, #T_f8a0b_row12_col5 {
#   background-color: #277f8e;
#   color: #f1f1f1;
# }
# #T_f8a0b_row1_col7, #T_f8a0b_row15_col6 {
#   background-color: #1f988b;
#   color: #f1f1f1;
# }
# #T_f8a0b_row1_col8, #T_f8a0b_row13_col7, #T_f8a0b_row27_col6 {
#   background-color: #25ab82;
#   color: #f1f1f1;
# }
# #T_f8a0b_row1_col9, #T_f8a0b_row1_col10, #T_f8a0b_row3_col9, #T_f8a0b_row3_col10, #T_f8a0b_row4_col8, #T_f8a0b_row5_col0, #T_f8a0b_row5_col1, #T_f8a0b_row5_col2, #T_f8a0b_row5_col3, #T_f8a0b_row5_col4, #T_f8a0b_row5_col5, #T_f8a0b_row5_col7, #T_f8a0b_row5_col8, #T_f8a0b_row5_col9, #T_f8a0b_row5_col10, #T_f8a0b_row7_col5, #T_f8a0b_row7_col8, #T_f8a0b_row8_col8, #T_f8a0b_row9_col9, #T_f8a0b_row9_col10, #T_f8a0b_row10_col2, #T_f8a0b_row10_col9, #T_f8a0b_row10_col10, #T_f8a0b_row15_col2, #T_f8a0b_row15_col5, #T_f8a0b_row15_col8, #T_f8a0b_row15_col9, #T_f8a0b_row15_col10, #T_f8a0b_row17_col2, #T_f8a0b_row17_col5, #T_f8a0b_row17_col8, #T_f8a0b_row17_col9, #T_f8a0b_row17_col10, #T_f8a0b_row19_col9, #T_f8a0b_row19_col10, #T_f8a0b_row20_col0, #T_f8a0b_row20_col1, #T_f8a0b_row20_col2, #T_f8a0b_row20_col3, #T_f8a0b_row20_col4, #T_f8a0b_row20_col5, #T_f8a0b_row20_col6, #T_f8a0b_row20_col7, #T_f8a0b_row20_col8, #T_f8a0b_row20_col10, #T_f8a0b_row23_col2, #T_f8a0b_row23_col5, #T_f8a0b_row23_col8, #T_f8a0b_row24_col10, #T_f8a0b_row25_col5, #T_f8a0b_row27_col9, #T_f8a0b_row27_col10, #T_f8a0b_row28_col9, #T_f8a0b_row28_col10, #T_f8a0b_row29_col9, #T_f8a0b_row30_col5, #T_f8a0b_row32_col8, #T_f8a0b_row32_col9, #T_f8a0b_row32_col10, #T_f8a0b_row34_col2, #T_f8a0b_row34_col5, #T_f8a0b_row34_col8, #T_f8a0b_row34_col9, #T_f8a0b_row34_col10, #T_f8a0b_row35_col9, #T_f8a0b_row35_col10, #T_f8a0b_row37_col8, #T_f8a0b_row37_col9, #T_f8a0b_row37_col10 {
#   background-color: #000000;
#   color: #f1f1f1;
# }
# #T_f8a0b_row2_col1, #T_f8a0b_row6_col1, #T_f8a0b_row8_col1, #T_f8a0b_row10_col1, #T_f8a0b_row13_col1, #T_f8a0b_row16_col1, #T_f8a0b_row17_col1, #T_f8a0b_row25_col1 {
#   background-color: #460b5e;
#   color: #f1f1f1;
# }
# #T_f8a0b_row2_col2, #T_f8a0b_row6_col2, #T_f8a0b_row8_col2, #T_f8a0b_row9_col2, #T_f8a0b_row28_col2, #T_f8a0b_row32_col2 {
#   background-color: #481a6c;
#   color: #f1f1f1;
# }
# #T_f8a0b_row2_col3 {
#   background-color: #472c7a;
#   color: #f1f1f1;
# }
# #T_f8a0b_row2_col4, #T_f8a0b_row10_col4 {
#   background-color: #3c508b;
#   color: #f1f1f1;
# }
# #T_f8a0b_row2_col5, #T_f8a0b_row6_col5 {
#   background-color: #2e6f8e;
#   color: #f1f1f1;
# }
# #T_f8a0b_row2_col6 {
#   background-color: #238a8d;
#   color: #f1f1f1;
# }
# #T_f8a0b_row2_col7, #T_f8a0b_row18_col6 {
#   background-color: #22a785;
#   color: #f1f1f1;
# }
# #T_f8a0b_row2_col8, #T_f8a0b_row12_col7 {
#   background-color: #38b977;
#   color: #f1f1f1;
# }
# #T_f8a0b_row2_col9, #T_f8a0b_row13_col9 {
#   background-color: #4cc26c;
#   color: #000000;
# }
# #T_f8a0b_row2_col10, #T_f8a0b_row8_col9, #T_f8a0b_row18_col8 {
#   background-color: #65cb5e;
#   color: #000000;
# }
# #T_f8a0b_row3_col3 {
#   background-color: #482979;
#   color: #f1f1f1;
# }
# #T_f8a0b_row3_col4 {
#   background-color: #3d4d8a;
#   color: #f1f1f1;
# }
# #T_f8a0b_row3_col5, #T_f8a0b_row10_col5, #T_f8a0b_row18_col4 {
#   background-color: #2f6c8e;
#   color: #f1f1f1;
# }
# #T_f8a0b_row3_col6, #T_f8a0b_row6_col6, #T_f8a0b_row14_col5 {
#   background-color: #24878e;
#   color: #f1f1f1;
# }
# #T_f8a0b_row3_col7, #T_f8a0b_row22_col6 {
#   background-color: #20a486;
#   color: #f1f1f1;
# }
# #T_f8a0b_row3_col8, #T_f8a0b_row16_col7 {
#   background-color: #32b67a;
#   color: #f1f1f1;
# }
# #T_f8a0b_row4_col0, #T_f8a0b_row7_col0, #T_f8a0b_row11_col0, #T_f8a0b_row12_col0, #T_f8a0b_row14_col0, #T_f8a0b_row26_col0, #T_f8a0b_row27_col0, #T_f8a0b_row30_col0, #T_f8a0b_row33_col0 {
#   background-color: #450559;
#   color: #f1f1f1;
# }
# #T_f8a0b_row4_col1, #T_f8a0b_row7_col1, #T_f8a0b_row12_col1, #T_f8a0b_row24_col1, #T_f8a0b_row30_col1, #T_f8a0b_row34_col1 {
#   background-color: #471164;
#   color: #f1f1f1;
# }
# #T_f8a0b_row4_col2, #T_f8a0b_row7_col2, #T_f8a0b_row12_col2 {
#   background-color: #482173;
#   color: #f1f1f1;
# }
# #T_f8a0b_row4_col3, #T_f8a0b_row7_col3 {
#   background-color: #453781;
#   color: #f1f1f1;
# }
# #T_f8a0b_row4_col4, #T_f8a0b_row7_col4 {
#   background-color: #365d8d;
#   color: #f1f1f1;
# }
# #T_f8a0b_row4_col5, #T_f8a0b_row30_col4 {
#   background-color: #297a8e;
#   color: #f1f1f1;
# }
# #T_f8a0b_row4_col6, #T_f8a0b_row26_col5 {
#   background-color: #1f978b;
#   color: #f1f1f1;
# }
# #T_f8a0b_row4_col7, #T_f8a0b_row8_col7, #T_f8a0b_row15_col7, #T_f8a0b_row24_col6 {
#   background-color: #29af7f;
#   color: #f1f1f1;
# }
# #T_f8a0b_row4_col9, #T_f8a0b_row11_col9, #T_f8a0b_row12_col8 {
#   background-color: #5cc863;
#   color: #000000;
# }
# #T_f8a0b_row4_col10, #T_f8a0b_row12_col9, #T_f8a0b_row32_col7 {
#   background-color: #75d054;
#   color: #000000;
# }
# #T_f8a0b_row5_col6, #T_f8a0b_row19_col6 {
#   background-color: #1f948c;
#   color: #f1f1f1;
# }
# #T_f8a0b_row6_col3, #T_f8a0b_row8_col3, #T_f8a0b_row10_col3, #T_f8a0b_row21_col3, #T_f8a0b_row28_col3 {
#   background-color: #472e7c;
#   color: #f1f1f1;
# }
# #T_f8a0b_row6_col4 {
#   background-color: #3b518b;
#   color: #f1f1f1;
# }
# #T_f8a0b_row6_col7 {
#   background-color: #1fa088;
#   color: #f1f1f1;
# }
# #T_f8a0b_row6_col8 {
#   background-color: #28ae80;
#   color: #f1f1f1;
# }
# #T_f8a0b_row6_col9, #T_f8a0b_row7_col7 {
#   background-color: #2db27d;
#   color: #f1f1f1;
# }
# #T_f8a0b_row6_col10, #T_f8a0b_row19_col8, #T_f8a0b_row30_col6 {
#   background-color: #48c16e;
#   color: #f1f1f1;
# }
# #T_f8a0b_row7_col6 {
#   background-color: #1f968b;
#   color: #f1f1f1;
# }
# #T_f8a0b_row7_col9, #T_f8a0b_row24_col7 {
#   background-color: #5ec962;
#   color: #000000;
# }
# #T_f8a0b_row7_col10, #T_f8a0b_row14_col10 {
#   background-color: #7ad151;
#   color: #000000;
# }
# #T_f8a0b_row8_col4 {
#   background-color: #39558c;
#   color: #f1f1f1;
# }
# #T_f8a0b_row8_col5 {
#   background-color: #2b748e;
#   color: #f1f1f1;
# }
# #T_f8a0b_row8_col6, #T_f8a0b_row13_col6, #T_f8a0b_row27_col5 {
#   background-color: #21918c;
#   color: #f1f1f1;
# }
# #T_f8a0b_row8_col10 {
#   background-color: #89d548;
#   color: #000000;
# }
# #T_f8a0b_row9_col3 {
#   background-color: #472d7b;
#   color: #f1f1f1;
# }
# #T_f8a0b_row9_col4 {
#   background-color: #3b528b;
#   color: #f1f1f1;
# }
# #T_f8a0b_row9_col5, #T_f8a0b_row24_col4, #T_f8a0b_row35_col4 {
#   background-color: #2c718e;
#   color: #f1f1f1;
# }
# #T_f8a0b_row9_col6 {
#   background-color: #218f8d;
#   color: #f1f1f1;
# }
# #T_f8a0b_row9_col8,
# <font color='green'>'mscoco_captions'</font> image_retrieval_recall@5 results for models pre-trained on <font color='red'>'datacomp_1b'</font>  using scheduler <font color='blue'>'cosine'</font>:
# <style type="text/css">
# #T_adefb_row0_col0, #T_adefb_row1_col0, #T_adefb_row6_col0, #T_adefb_row8_col0, #T_adefb_row9_col0, #T_adefb_row10_col0, #T_adefb_row13_col0, #T_adefb_row16_col0, #T_adefb_row19_col0, #T_adefb_row21_col1, #T_adefb_row25_col0, #T_adefb_row29_col0 {
#   background-color: #440256;
#   color: #f1f1f1;
# }
# #T_adefb_row0_col1, #T_adefb_row2_col1, #T_adefb_row6_col1, #T_adefb_row8_col1, #T_adefb_row9_col1, #T_adefb_row10_col1, #T_adefb_row13_col1, #T_adefb_row17_col1, #T_adefb_row28_col1 {
#   background-color: #470d60;
#   color: #f1f1f1;
# }
# #T_adefb_row0_col2, #T_adefb_row3_col2, #T_adefb_row9_col2 {
#   background-color: #481b6d;
#   color: #f1f1f1;
# }
# #T_adefb_row0_col3, #T_adefb_row26_col2 {
#   background-color: #472e7c;
#   color: #f1f1f1;
# }
# #T_adefb_row0_col4, #T_adefb_row26_col3, #T_adefb_row34_col3 {
#   background-color: #3c4f8a;
#   color: #f1f1f1;
# }
# #T_adefb_row0_col5, #T_adefb_row22_col4 {
#   background-color: #2f6b8e;
#   color: #f1f1f1;
# }
# #T_adefb_row0_col6, #T_adefb_row16_col5, #T_adefb_row21_col5, #T_adefb_row30_col4 {
#   background-color: #26828e;
#   color: #f1f1f1;
# }
# #T_adefb_row0_col7, #T_adefb_row10_col7, #T_adefb_row15_col6 {
#   background-color: #1f9a8a;
#   color: #f1f1f1;
# }
# #T_adefb_row0_col8, #T_adefb_row1_col8, #T_adefb_row10_col8 {
#   background-color: #24aa83;
#   color: #f1f1f1;
# }
# #T_adefb_row0_col9, #T_adefb_row2_col8, #T_adefb_row16_col7, #T_adefb_row24_col6, #T_adefb_row31_col6 {
#   background-color: #34b679;
#   color: #f1f1f1;
# }
# #T_adefb_row0_col10, #T_adefb_row13_col8 {
#   background-color: #3fbc73;
#   color: #f1f1f1;
# }
# #T_adefb_row1_col1, #T_adefb_row3_col1, #T_adefb_row16_col1, #T_adefb_row25_col1 {
#   background-color: #460b5e;
#   color: #f1f1f1;
# }
# #T_adefb_row1_col2 {
#   background-color: #481a6c;
#   color: #f1f1f1;
# }
# #T_adefb_row1_col3, #T_adefb_row27_col2 {
#   background-color: #472d7b;
#   color: #f1f1f1;
# }
# #T_adefb_row1_col4, #T_adefb_row30_col3, #T_adefb_row33_col3 {
#   background-color: #3d4e8a;
#   color: #f1f1f1;
# }
# #T_adefb_row1_col5, #T_adefb_row15_col4 {
#   background-color: #30698e;
#   color: #f1f1f1;
# }
# #T_adefb_row1_col6, #T_adefb_row34_col4 {
#   background-color: #26818e;
#   color: #f1f1f1;
# }
# #T_adefb_row1_col7 {
#   background-color: #1f988b;
#   color: #f1f1f1;
# }
# #T_adefb_row1_col9, #T_adefb_row1_col10, #T_adefb_row3_col9, #T_adefb_row3_col10, #T_adefb_row4_col8, #T_adefb_row5_col0, #T_adefb_row5_col1, #T_adefb_row5_col2, #T_adefb_row5_col3, #T_adefb_row5_col4, #T_adefb_row5_col5, #T_adefb_row5_col7, #T_adefb_row5_col8, #T_adefb_row5_col9, #T_adefb_row5_col10, #T_adefb_row7_col5, #T_adefb_row7_col8, #T_adefb_row8_col8, #T_adefb_row9_col9, #T_adefb_row9_col10, #T_adefb_row10_col2, #T_adefb_row10_col9, #T_adefb_row10_col10, #T_adefb_row15_col2, #T_adefb_row15_col5, #T_adefb_row15_col8, #T_adefb_row15_col9, #T_adefb_row15_col10, #T_adefb_row17_col2, #T_adefb_row17_col5, #T_adefb_row17_col8, #T_adefb_row17_col9, #T_adefb_row17_col10, #T_adefb_row19_col9, #T_adefb_row19_col10, #T_adefb_row20_col0, #T_adefb_row20_col1, #T_adefb_row20_col2, #T_adefb_row20_col3, #T_adefb_row20_col4, #T_adefb_row20_col5, #T_adefb_row20_col6, #T_adefb_row20_col7, #T_adefb_row20_col8, #T_adefb_row20_col10, #T_adefb_row23_col2, #T_adefb_row23_col5, #T_adefb_row23_col8, #T_adefb_row24_col10, #T_adefb_row25_col5, #T_adefb_row27_col9, #T_adefb_row27_col10, #T_adefb_row28_col9, #T_adefb_row28_col10, #T_adefb_row29_col9, #T_adefb_row30_col5, #T_adefb_row32_col8, #T_adefb_row32_col9, #T_adefb_row32_col10, #T_adefb_row34_col2, #T_adefb_row34_col5, #T_adefb_row34_col8, #T_adefb_row34_col9, #T_adefb_row34_col10, #T_adefb_row35_col9, #T_adefb_row35_col10, #T_adefb_row37_col8, #T_adefb_row37_col9, #T_adefb_row37_col10 {
#   background-color: #000000;
#   color: #f1f1f1;
# }
# #T_adefb_row2_col0, #T_adefb_row3_col0, #T_adefb_row17_col0, #T_adefb_row31_col0, #T_adefb_row36_col0, #T_adefb_row37_col0 {
#   background-color: #450457;
#   color: #f1f1f1;
# }
# #T_adefb_row2_col2, #T_adefb_row8_col2, #T_adefb_row13_col2, #T_adefb_row21_col2, #T_adefb_row25_col2, #T_adefb_row28_col2 {
#   background-color: #481d6f;
#   color: #f1f1f1;
# }
# #T_adefb_row2_col3, #T_adefb_row3_col3 {
#   background-color: #46307e;
#   color: #f1f1f1;
# }
# #T_adefb_row2_col4 {
#   background-color: #3a548c;
#   color: #f1f1f1;
# }
# #T_adefb_row2_col5 {
#   background-color: #2c718e;
#   color: #f1f1f1;
# }
# #T_adefb_row2_col6 {
#   background-color: #228b8d;
#   color: #f1f1f1;
# }
# #T_adefb_row2_col7, #T_adefb_row17_col7 {
#   background-color: #21a585;
#   color: #f1f1f1;
# }
# #T_adefb_row2_col9, #T_adefb_row14_col8, #T_adefb_row22_col7, #T_adefb_row23_col7, #T_adefb_row27_col7 {
#   background-color: #4ec36b;
#   color: #000000;
# }
# #T_adefb_row2_col10, #T_adefb_row8_col9, #T_adefb_row37_col6, #T_adefb_row38_col6 {
#   background-color: #65cb5e;
#   color: #000000;
# }
# #T_adefb_row3_col4 {
#   background-color: #3b528b;
#   color: #f1f1f1;
# }
# #T_adefb_row3_col5 {
#   background-color: #2e6f8e;
#   color: #f1f1f1;
# }
# #T_adefb_row3_col6, #T_adefb_row6_col6, #T_adefb_row11_col5 {
#   background-color: #238a8d;
#   color: #f1f1f1;
# }
# #T_adefb_row3_col7 {
#   background-color: #20a386;
#   color: #f1f1f1;
# }
# #T_adefb_row3_col8, #T_adefb_row14_col7 {
#   background-color: #32b67a;
#   color: #f1f1f1;
# }
# #T_adefb_row4_col0, #T_adefb_row7_col0, #T_adefb_row15_col0, #T_adefb_row27_col0, #T_adefb_row34_col0 {
#   background-color: #46085c;
#   color: #f1f1f1;
# }
# #T_adefb_row4_col1, #T_adefb_row11_col1, #T_adefb_row24_col1, #T_adefb_row30_col1, #T_adefb_row33_col1, #T_adefb_row34_col1 {
#   background-color: #481467;
#   color: #f1f1f1;
# }
# #T_adefb_row4_col2, #T_adefb_row12_col2, #T_adefb_row38_col2 {
#   background-color: #482576;
#   color: #f1f1f1;
# }
# #T_adefb_row4_col3, #T_adefb_row25_col3 {
#   background-color: #443b84;
#   color: #f1f1f1;
# }
# #T_adefb_row4_col4, #T_adefb_row19_col4 {
#   background-color: #34618d;
#   color: #f1f1f1;
# }
# #T_adefb_row4_col5, #T_adefb_row19_col5, #T_adefb_row37_col4 {
#   background-color: #287d8e;
#   color: #f1f1f1;
# }
# #T_adefb_row4_col6, #T_adefb_row29_col5 {
#   background-color: #1f998a;
#   color: #f1f1f1;
# }
# #T_adefb_row4_col7, #T_adefb_row6_col8, #T_adefb_row15_col7 {
#   background-color: #29af7f;
#   color: #f1f1f1;
# }
# #T_adefb_row4_col9, #T_adefb_row11_col9, #T_adefb_row33_col6 {
#   background-color: #5cc863;
#   color: #000000;
# }
# #T_adefb_row4_col10, #T_adefb_row13_col10 {
#   background-color: #6ccd5a;
#   color: #000000;
# }
# #T_adefb_row5_col6, #T_adefb_row27_col5 {
#   background-color: #1f968b;
#   color: #f1f1f1;
# }
# #T_adefb_row6_col2, #T_adefb_row16_col2, #T_adefb_row32_col2 {
#   background-color: #481c6e;
#   color: #f1f1f1;
# }
# #T_adefb_row6_col3 {
#   background-color: #46337f;
#   color: #f1f1f1;
# }
# #T_adefb_row6_col4, #T_adefb_row10_col4 {
#   background-color: #39568c;
#   color: #f1f1f1;
# }
# #T_adefb_row6_col5 {
#   background-color: #2c728e;
#   color: #f1f1f1;
# }
# #T_adefb_row6_col7, #T_adefb_row21_col6, #T_adefb_row26_col5 {
#   background-color: #1fa088;
#   color: #f1f1f1;
# }
# #T_adefb_row6_col9, #T_adefb_row25_col6 {
#   background-color: #2ab07f;
#   color: #f1f1f1;
# }
# #T_adefb_row6_col10 {
#   background-color: #46c06f;
#   color: #f1f1f1;
# }
# #T_adefb_row7_col1, #T_adefb_row12_col1, #T_adefb_row15_col1, #T_adefb_row23_col1 {
#   background-color: #481668;
#   color: #f1f1f1;
# }
# #T_adefb_row7_col2, #T_adefb_row37_col2 {
#   background-color: #482475;
#   color: #f1f1f1;
# }
# #T_adefb_row7_col3 {
#   background-color: #423f85;
#   color: #f1f1f1;
# }
# #T_adefb_row7_col4, #T_adefb_row16_col4 {
#   background-color: #33638d;
#   color: #f1f1f1;
# }
# #T_adefb_row7_col6 {
#   background-color: #1f978b;
#   color: #f1f1f1;
# }
# #T_adefb_row7_col7, #T_adefb_row8_col7, #T_adefb_row33_col5 {
#   background-color: #28ae80;
#   color: #f1f1f1;
# }
# #T_adefb_row7_col9 {
#   background-color: #5ec962;
#   color: #000000;
# }
# #T_adefb_row7_col10, #T_adefb_row16_col9, #T_adefb_row21_col8, #T_adefb_row31_col7, #T_adefb_row34_col7 {
#   background-color: #75d054;
#   color: #000000;
# }
# #T_adefb_row8_col3 {
#   background-color: #463480;
#   color: #f1f1f1;
# }
# #T_adefb_row8_col4, #T_adefb_row21_col4 {
#   background-color: #38598c;
#   color: #f1f1f1;
# }
# #T_adefb_row8_col5, #T_adefb_row36_col4 {
#   backg
# <font color='green'>'mscoco_captions'</font> text_retrieval_recall@5 results for models pre-trained on <font color='red'>'datacomp_1b'</font>  using scheduler <font color='blue'>'cosine'</font>:
# <style type="text/css">
# #T_421af_row0_col0, #T_421af_row2_col0, #T_421af_row3_col0, #T_421af_row6_col0, #T_421af_row13_col0, #T_421af_row19_col0, #T_421af_row25_col0 {
#   background-color: #450457;
#   color: #f1f1f1;
# }
# #T_421af_row0_col1, #T_421af_row1_col1, #T_421af_row2_col1, #T_421af_row9_col1, #T_421af_row19_col1, #T_421af_row25_col1, #T_421af_row28_col1, #T_421af_row31_col1, #T_421af_row32_col1 {
#   background-color: #470e61;
#   color: #f1f1f1;
# }
# #T_421af_row0_col2 {
#   background-color: #482475;
#   color: #f1f1f1;
# }
# #T_421af_row0_col3 {
#   background-color: #433d84;
#   color: #f1f1f1;
# }
# #T_421af_row0_col4, #T_421af_row33_col3 {
#   background-color: #34608d;
#   color: #f1f1f1;
# }
# #T_421af_row0_col5 {
#   background-color: #27808e;
#   color: #f1f1f1;
# }
# #T_421af_row0_col6, #T_421af_row33_col4 {
#   background-color: #1e9b8a;
#   color: #f1f1f1;
# }
# #T_421af_row0_col7, #T_421af_row21_col6, #T_421af_row31_col5 {
#   background-color: #2eb37c;
#   color: #f1f1f1;
# }
# #T_421af_row0_col8, #T_421af_row25_col6 {
#   background-color: #4ac16d;
#   color: #000000;
# }
# #T_421af_row0_col9, #T_421af_row34_col6, #T_421af_row35_col6 {
#   background-color: #60ca60;
#   color: #000000;
# }
# #T_421af_row0_col10 {
#   background-color: #6ece58;
#   color: #000000;
# }
# #T_421af_row1_col0, #T_421af_row8_col0, #T_421af_row9_col0, #T_421af_row16_col0, #T_421af_row21_col1, #T_421af_row28_col0 {
#   background-color: #440256;
#   color: #f1f1f1;
# }
# #T_421af_row1_col2, #T_421af_row9_col2 {
#   background-color: #482374;
#   color: #f1f1f1;
# }
# #T_421af_row1_col3 {
#   background-color: #443a83;
#   color: #f1f1f1;
# }
# #T_421af_row1_col4 {
#   background-color: #355f8d;
#   color: #f1f1f1;
# }
# #T_421af_row1_col5 {
#   background-color: #297b8e;
#   color: #f1f1f1;
# }
# #T_421af_row1_col6, #T_421af_row12_col5, #T_421af_row16_col5, #T_421af_row21_col5, #T_421af_row34_col4 {
#   background-color: #1f998a;
#   color: #f1f1f1;
# }
# #T_421af_row1_col7, #T_421af_row27_col5 {
#   background-color: #28ae80;
#   color: #f1f1f1;
# }
# #T_421af_row1_col8, #T_421af_row17_col7 {
#   background-color: #44bf70;
#   color: #f1f1f1;
# }
# #T_421af_row1_col9, #T_421af_row1_col10, #T_421af_row3_col9, #T_421af_row3_col10, #T_421af_row4_col8, #T_421af_row5_col0, #T_421af_row5_col1, #T_421af_row5_col2, #T_421af_row5_col3, #T_421af_row5_col4, #T_421af_row5_col5, #T_421af_row5_col7, #T_421af_row5_col8, #T_421af_row5_col9, #T_421af_row5_col10, #T_421af_row7_col5, #T_421af_row7_col8, #T_421af_row8_col8, #T_421af_row9_col9, #T_421af_row9_col10, #T_421af_row10_col2, #T_421af_row10_col9, #T_421af_row10_col10, #T_421af_row15_col2, #T_421af_row15_col5, #T_421af_row15_col8, #T_421af_row15_col9, #T_421af_row15_col10, #T_421af_row17_col2, #T_421af_row17_col5, #T_421af_row17_col8, #T_421af_row17_col9, #T_421af_row17_col10, #T_421af_row19_col9, #T_421af_row19_col10, #T_421af_row20_col0, #T_421af_row20_col1, #T_421af_row20_col2, #T_421af_row20_col3, #T_421af_row20_col4, #T_421af_row20_col5, #T_421af_row20_col6, #T_421af_row20_col7, #T_421af_row20_col8, #T_421af_row20_col10, #T_421af_row23_col2, #T_421af_row23_col5, #T_421af_row23_col8, #T_421af_row24_col10, #T_421af_row25_col5, #T_421af_row27_col9, #T_421af_row27_col10, #T_421af_row28_col9, #T_421af_row28_col10, #T_421af_row29_col9, #T_421af_row30_col5, #T_421af_row32_col8, #T_421af_row32_col9, #T_421af_row32_col10, #T_421af_row34_col2, #T_421af_row34_col5, #T_421af_row34_col8, #T_421af_row34_col9, #T_421af_row34_col10, #T_421af_row35_col9, #T_421af_row35_col10, #T_421af_row37_col8, #T_421af_row37_col9, #T_421af_row37_col10 {
#   background-color: #000000;
#   color: #f1f1f1;
# }
# #T_421af_row2_col2, #T_421af_row16_col2, #T_421af_row21_col2, #T_421af_row28_col2 {
#   background-color: #482677;
#   color: #f1f1f1;
# }
# #T_421af_row2_col3, #T_421af_row21_col3, #T_421af_row28_col3 {
#   background-color: #423f85;
#   color: #f1f1f1;
# }
# #T_421af_row2_col4 {
#   background-color: #306a8e;
#   color: #f1f1f1;
# }
# #T_421af_row2_col5, #T_421af_row6_col5 {
#   background-color: #23888e;
#   color: #f1f1f1;
# }
# #T_421af_row2_col6 {
#   background-color: #1fa287;
#   color: #f1f1f1;
# }
# #T_421af_row2_col7 {
#   background-color: #40bd72;
#   color: #f1f1f1;
# }
# #T_421af_row2_col8, #T_421af_row36_col6 {
#   background-color: #67cc5c;
#   color: #000000;
# }
# #T_421af_row2_col9, #T_421af_row22_col7 {
#   background-color: #81d34d;
#   color: #000000;
# }
# #T_421af_row2_col10, #T_421af_row14_col9, #T_421af_row25_col7, #T_421af_row29_col7 {
#   background-color: #90d743;
#   color: #000000;
# }
# #T_421af_row3_col1, #T_421af_row16_col1 {
#   background-color: #471063;
#   color: #f1f1f1;
# }
# #T_421af_row3_col2 {
#   background-color: #482173;
#   color: #f1f1f1;
# }
# #T_421af_row3_col3 {
#   background-color: #433e85;
#   color: #f1f1f1;
# }
# #T_421af_row3_col4 {
#   background-color: #32648e;
#   color: #f1f1f1;
# }
# #T_421af_row3_col5, #T_421af_row15_col4, #T_421af_row23_col4, #T_421af_row25_col4 {
#   background-color: #26828e;
#   color: #f1f1f1;
# }
# #T_421af_row3_col6 {
#   background-color: #1fa187;
#   color: #f1f1f1;
# }
# #T_421af_row3_col7, #T_421af_row22_col6, #T_421af_row23_col6, #T_421af_row37_col5 {
#   background-color: #3fbc73;
#   color: #f1f1f1;
# }
# #T_421af_row3_col8, #T_421af_row16_col7, #T_421af_row32_col6 {
#   background-color: #5ec962;
#   color: #000000;
# }
# #T_421af_row4_col0, #T_421af_row11_col0, #T_421af_row12_col0, #T_421af_row22_col0, #T_421af_row24_col0 {
#   background-color: #46085c;
#   color: #f1f1f1;
# }
# #T_421af_row4_col1, #T_421af_row11_col1, #T_421af_row14_col1, #T_421af_row24_col1 {
#   background-color: #481a6c;
#   color: #f1f1f1;
# }
# #T_421af_row4_col2, #T_421af_row7_col2, #T_421af_row35_col2, #T_421af_row38_col2 {
#   background-color: #46307e;
#   color: #f1f1f1;
# }
# #T_421af_row4_col3, #T_421af_row7_col3 {
#   background-color: #3d4e8a;
#   color: #f1f1f1;
# }
# #T_421af_row4_col4, #T_421af_row7_col4, #T_421af_row19_col4 {
#   background-color: #2b758e;
#   color: #f1f1f1;
# }
# #T_421af_row4_col5, #T_421af_row19_col5, #T_421af_row26_col4 {
#   background-color: #1f968b;
#   color: #f1f1f1;
# }
# #T_421af_row4_col6, #T_421af_row7_col6 {
#   background-color: #2ab07f;
#   color: #f1f1f1;
# }
# #T_421af_row4_col7, #T_421af_row8_col7, #T_421af_row19_col7 {
#   background-color: #52c569;
#   color: #000000;
# }
# #T_421af_row4_col9, #T_421af_row7_col9 {
#   background-color: #89d548;
#   color: #000000;
# }
# #T_421af_row4_col10, #T_421af_row11_col10, #T_421af_row34_col7 {
#   background-color: #9bd93c;
#   color: #000000;
# }
# #T_421af_row5_col6, #T_421af_row29_col5 {
#   background-color: #29af7f;
#   color: #f1f1f1;
# }
# #T_421af_row6_col1, #T_421af_row8_col1, #T_421af_row13_col1, #T_421af_row17_col1, #T_421af_row22_col1 {
#   background-color: #471164;
#   color: #f1f1f1;
# }
# #T_421af_row6_col2, #T_421af_row32_col2 {
#   background-color: #482576;
#   color: #f1f1f1;
# }
# #T_421af_row6_col3, #T_421af_row8_col3 {
#   background-color: #414287;
#   color: #f1f1f1;
# }
# #T_421af_row6_col4 {
#   background-color: #2f6b8e;
#   color: #f1f1f1;
# }
# #T_421af_row6_col6 {
#   background-color: #20a486;
#   color: #f1f1f1;
# }
# #T_421af_row6_col7, #T_421af_row11_col6, #T_421af_row36_col5 {
#   background-color: #34b679;
#   color: #f1f1f1;
# }
# #T_421af_row6_col8 {
#   background-color: #56c667;
#   color: #000000;
# }
# #T_421af_row6_col9 {
#   background-color: #58c765;
#   color: #000000;
# }
# #T_421af_row6_col10, #T_421af_row18_col7, #T_421af_row33_col6 {
#   background-color: #7ad151;
#   color: #000000;
# }
# #T_421af_row7_col0, #T_421af_row15_col0, #T_421af_row26_col0, #T_421af_row29_col1 {
#   background-color: #460b5e;
#   color: #f1f1f1;
# }
# #T_421af_row7_col1, #T_421af_row18_col1 {
#   background-color: #481b6d;
#   color: #f1f1f1;
# }
# #T_421af_row7_col7, #T_421af_row10_col8, #T_421af_row27_col6 {
#   background-color: #4cc26c;
#   color: #000000;
# }
# #T_421af_row7_col10, #T_421af_row13_col10, #T_421af_row16_col9, #T_421af_row21_col8, #T_421af_row26_col7, #T_421af_row35_col7 {
#   background-color: #a0da39;
#   color: #000000;
# }
# #T_421af_row8_col2, #T_421af_row25_col2 {
#   background-color: #482878;
#   color: #f1f1f1;
# }
# #T_421af_row8_col4, #T_421af_row21_col4 {
#   background-color: #2f6c8e;
#   color: #f1f1f1;
# }
# #T_421af_row8_col5, #T_421af_row27_col4 {
#   background-color: #218f8d;
#   color: #f1f1f1;
# }
# #T_
# <font color='green'>'datacomp_classification'</font> acc1 results for models pre-trained on <font color='red'>'datacomp_1b'</font>  using scheduler <font color='blue'>'cosine'</font>:
# <style type="text/css">
# #T_1ee18_row0_col0, #T_1ee18_row10_col0 {
#   background-color: #450559;
#   color: #f1f1f1;
# }
# #T_1ee18_row0_col1, #T_1ee18_row2_col1, #T_1ee18_row13_col1, #T_1ee18_row14_col1 {
#   background-color: #481467;
#   color: #f1f1f1;
# }
# #T_1ee18_row0_col2 {
#   background-color: #472a7a;
#   color: #f1f1f1;
# }
# #T_1ee18_row0_col3 {
#   background-color: #433e85;
#   color: #f1f1f1;
# }
# #T_1ee18_row0_col4, #T_1ee18_row1_col4 {
#   background-color: #365c8d;
#   color: #f1f1f1;
# }
# #T_1ee18_row0_col5 {
#   background-color: #2b758e;
#   color: #f1f1f1;
# }
# #T_1ee18_row0_col6 {
#   background-color: #228b8d;
#   color: #f1f1f1;
# }
# #T_1ee18_row0_col7, #T_1ee18_row22_col5 {
#   background-color: #1fa187;
#   color: #f1f1f1;
# }
# #T_1ee18_row0_col8 {
#   background-color: #28ae80;
#   color: #f1f1f1;
# }
# #T_1ee18_row0_col9 {
#   background-color: #3dbc74;
#   color: #f1f1f1;
# }
# #T_1ee18_row0_col10, #T_1ee18_row16_col7 {
#   background-color: #44bf70;
#   color: #f1f1f1;
# }
# #T_1ee18_row1_col0, #T_1ee18_row19_col0, #T_1ee18_row21_col0 {
#   background-color: #460a5d;
#   color: #f1f1f1;
# }
# #T_1ee18_row1_col1, #T_1ee18_row15_col1, #T_1ee18_row19_col1 {
#   background-color: #471365;
#   color: #f1f1f1;
# }
# #T_1ee18_row1_col2 {
#   background-color: #482677;
#   color: #f1f1f1;
# }
# #T_1ee18_row1_col3, #T_1ee18_row19_col2, #T_1ee18_row20_col2 {
#   background-color: #443983;
#   color: #f1f1f1;
# }
# #T_1ee18_row1_col5 {
#   background-color: #2c728e;
#   color: #f1f1f1;
# }
# #T_1ee18_row1_col6 {
#   background-color: #23888e;
#   color: #f1f1f1;
# }
# #T_1ee18_row1_col7, #T_1ee18_row13_col6 {
#   background-color: #1f9f88;
#   color: #f1f1f1;
# }
# #T_1ee18_row1_col8, #T_1ee18_row7_col7 {
#   background-color: #29af7f;
#   color: #f1f1f1;
# }
# #T_1ee18_row1_col9, #T_1ee18_row1_col10, #T_1ee18_row3_col0, #T_1ee18_row3_col1, #T_1ee18_row3_col2, #T_1ee18_row3_col3, #T_1ee18_row3_col4, #T_1ee18_row3_col5, #T_1ee18_row3_col8, #T_1ee18_row3_col9, #T_1ee18_row3_col10, #T_1ee18_row4_col8, #T_1ee18_row6_col2, #T_1ee18_row6_col5, #T_1ee18_row6_col8, #T_1ee18_row7_col9, #T_1ee18_row7_col10, #T_1ee18_row8_col0, #T_1ee18_row8_col2, #T_1ee18_row8_col3, #T_1ee18_row8_col5, #T_1ee18_row8_col8, #T_1ee18_row8_col9, #T_1ee18_row8_col10, #T_1ee18_row11_col0, #T_1ee18_row11_col1, #T_1ee18_row11_col2, #T_1ee18_row11_col4, #T_1ee18_row11_col5, #T_1ee18_row11_col6, #T_1ee18_row11_col7, #T_1ee18_row11_col8, #T_1ee18_row11_col9, #T_1ee18_row11_col10, #T_1ee18_row12_col2, #T_1ee18_row12_col5, #T_1ee18_row12_col8, #T_1ee18_row12_col9, #T_1ee18_row12_col10, #T_1ee18_row14_col2, #T_1ee18_row14_col5, #T_1ee18_row14_col8, #T_1ee18_row14_col9, #T_1ee18_row14_col10, #T_1ee18_row15_col9, #T_1ee18_row15_col10, #T_1ee18_row18_col9, #T_1ee18_row18_col10, #T_1ee18_row21_col2, #T_1ee18_row21_col5, #T_1ee18_row21_col8, #T_1ee18_row21_col9, #T_1ee18_row21_col10, #T_1ee18_row23_col10 {
#   background-color: #000000;
#   color: #f1f1f1;
# }
# #T_1ee18_row2_col0, #T_1ee18_row4_col0, #T_1ee18_row7_col0, #T_1ee18_row9_col0, #T_1ee18_row13_col0, #T_1ee18_row16_col0, #T_1ee18_row20_col0, #T_1ee18_row22_col0, #T_1ee18_row23_col0 {
#   background-color: #46085c;
#   color: #f1f1f1;
# }
# #T_1ee18_row2_col2, #T_1ee18_row13_col2 {
#   background-color: #472d7b;
#   color: #f1f1f1;
# }
# #T_1ee18_row2_col3 {
#   background-color: #424186;
#   color: #f1f1f1;
# }
# #T_1ee18_row2_col4 {
#   background-color: #355f8d;
#   color: #f1f1f1;
# }
# #T_1ee18_row2_col5, #T_1ee18_row5_col5, #T_1ee18_row7_col5 {
#   background-color: #297b8e;
#   color: #f1f1f1;
# }
# #T_1ee18_row2_col6, #T_1ee18_row18_col5 {
#   background-color: #20928c;
#   color: #f1f1f1;
# }
# #T_1ee18_row2_col7 {
#   background-color: #25ab82;
#   color: #f1f1f1;
# }
# #T_1ee18_row2_col8 {
#   background-color: #3fbc73;
#   color: #f1f1f1;
# }
# #T_1ee18_row2_col9, #T_1ee18_row23_col6 {
#   background-color: #56c667;
#   color: #000000;
# }
# #T_1ee18_row2_col10 {
#   background-color: #5cc863;
#   color: #000000;
# }
# #T_1ee18_row3_col6, #T_1ee18_row16_col5 {
#   background-color: #218f8d;
#   color: #f1f1f1;
# }
# #T_1ee18_row3_col7 {
#   background-color: #23a983;
#   color: #f1f1f1;
# }
# #T_1ee18_row4_col1, #T_1ee18_row12_col1, #T_1ee18_row17_col1, #T_1ee18_row20_col1, #T_1ee18_row21_col1 {
#   background-color: #481d6f;
#   color: #f1f1f1;
# }
# #T_1ee18_row4_col2 {
#   background-color: #46337f;
#   color: #f1f1f1;
# }
# #T_1ee18_row4_col3 {
#   background-color: #3f4788;
#   color: #f1f1f1;
# }
# #T_1ee18_row4_col4 {
#   background-color: #31688e;
#   color: #f1f1f1;
# }
# #T_1ee18_row4_col5, #T_1ee18_row15_col5, #T_1ee18_row23_col4 {
#   background-color: #26828e;
#   color: #f1f1f1;
# }
# #T_1ee18_row4_col6 {
#   background-color: #1f9a8a;
#   color: #f1f1f1;
# }
# #T_1ee18_row4_col7 {
#   background-color: #2db27d;
#   color: #f1f1f1;
# }
# #T_1ee18_row4_col9 {
#   background-color: #52c569;
#   color: #000000;
# }
# #T_1ee18_row4_col10 {
#   background-color: #67cc5c;
#   color: #000000;
# }
# #T_1ee18_row5_col0, #T_1ee18_row15_col0, #T_1ee18_row18_col0 {
#   background-color: #46075a;
#   color: #f1f1f1;
# }
# #T_1ee18_row5_col1, #T_1ee18_row6_col1, #T_1ee18_row10_col1 {
#   background-color: #481769;
#   color: #f1f1f1;
# }
# #T_1ee18_row5_col2, #T_1ee18_row7_col2 {
#   background-color: #472c7a;
#   color: #f1f1f1;
# }
# #T_1ee18_row5_col3, #T_1ee18_row7_col3 {
#   background-color: #414287;
#   color: #f1f1f1;
# }
# #T_1ee18_row5_col4 {
#   background-color: #33628d;
#   color: #f1f1f1;
# }
# #T_1ee18_row5_col6 {
#   background-color: #218e8d;
#   color: #f1f1f1;
# }
# #T_1ee18_row5_col7, #T_1ee18_row20_col5 {
#   background-color: #20a486;
#   color: #f1f1f1;
# }
# #T_1ee18_row5_col8, #T_1ee18_row9_col7 {
#   background-color: #2fb47c;
#   color: #f1f1f1;
# }
# #T_1ee18_row5_col9 {
#   background-color: #32b67a;
#   color: #f1f1f1;
# }
# #T_1ee18_row5_col10 {
#   background-color: #4cc26c;
#   color: #000000;
# }
# #T_1ee18_row6_col0, #T_1ee18_row12_col0 {
#   background-color: #450457;
#   color: #f1f1f1;
# }
# #T_1ee18_row6_col3, #T_1ee18_row10_col3, #T_1ee18_row14_col3 {
#   background-color: #414487;
#   color: #f1f1f1;
# }
# #T_1ee18_row6_col4 {
#   background-color: #32648e;
#   color: #f1f1f1;
# }
# #T_1ee18_row6_col6 {
#   background-color: #1f988b;
#   color: #f1f1f1;
# }
# #T_1ee18_row6_col7, #T_1ee18_row19_col6 {
#   background-color: #2eb37c;
#   color: #f1f1f1;
# }
# #T_1ee18_row6_col9 {
#   background-color: #65cb5e;
#   color: #000000;
# }
# #T_1ee18_row6_col10 {
#   background-color: #90d743;
#   color: #000000;
# }
# #T_1ee18_row7_col1, #T_1ee18_row8_col1, #T_1ee18_row16_col1 {
#   background-color: #481668;
#   color: #f1f1f1;
# }
# #T_1ee18_row7_col4 {
#   background-color: #33638d;
#   color: #f1f1f1;
# }
# #T_1ee18_row7_col6 {
#   background-color: #1f948c;
#   color: #f1f1f1;
# }
# #T_1ee18_row7_col8 {
#   background-color: #4ac16d;
#   color: #000000;
# }
# #T_1ee18_row8_col4 {
#   background-color: #355e8d;
#   color: #f1f1f1;
# }
# #T_1ee18_row8_col6 {
#   background-color: #23898e;
#   color: #f1f1f1;
# }
# #T_1ee18_row8_col7 {
#   background-color: #1fa188;
#   color: #f1f1f1;
# }
# #T_1ee18_row9_col1 {
#   background-color: #481f70;
#   color: #f1f1f1;
# }
# #T_1ee18_row9_col2 {
#   background-color: #453882;
#   color: #f1f1f1;
# }
# #T_1ee18_row9_col3, #T_1ee18_row22_col3 {
#   background-color: #3d4e8a;
#   color: #f1f1f1;
# }
# #T_1ee18_row9_col4 {
#   background-color: #2d718e;
#   color: #f1f1f1;
# }
# #T_1ee18_row9_col5 {
#   background-color: #24878e;
#   color: #f1f1f1;
# }
# #T_1ee18_row9_col6 {
#   background-color: #1f9e89;
#   color: #f1f1f1;
# }
# #T_1ee18_row9_col8 {
#   background-color: #46c06f;
#   color: #f1f1f1;
# }
# #T_1ee18_row9_col9 {
#   background-color: #5ac864;
#   color: #000000;
# }
# #T_1ee18_row9_col10, #T_1ee18_row18_col8, #T_1ee18_row22_col7 {
#   background-color: #77d153;
#   color: #000000;
# }
# #T_1ee18_row10_col2 {
#   background-color: #472e7c;
#   color: #f1f1f1;
# }
# #T_1ee18_row10_col4, #T_1ee18_row15_col4 {
#   background-color: #30698e;
#   color: #f1f1f1;
# }
# #T_1ee18_row10_col5 {
#   background-color: #277e8e;
#   color: #f1f1f1;
# }
# #T_1ee18_row10_col6 {
#   background-color: #1f968b;
#   color: #f1f1f1;
# }
# #T_1ee18_row10_col7, #T_1ee18_row12_col7 {
#   background-color: #27ad81;
#   color: #f1f1f1;
# }
# #T_1ee18_row10_col8 {
#   background-color: #40bd72;
#   color: #f1f1f1;
# }
# #T_1ee18_row10_col9, #T_1ee18_row15_col8 {
#   background-color: #4ec36b;
#   color: #000000;
# }
# #T_1ee18_row10_col10, #T_1ee18_row17_col7 {
#   back
# <font color='green'>'imagenet_distribution_shift'</font> acc1 results for models pre-trained on <font color='red'>'datacomp_1b'</font>  using scheduler <font color='blue'>'cosine'</font>:
# <style type="text/css">
# #T_9e010_row0_col0, #T_9e010_row1_col0, #T_9e010_row2_col0, #T_9e010_row5_col0, #T_9e010_row6_col0, #T_9e010_row7_col0, #T_9e010_row8_col0, #T_9e010_row10_col0, #T_9e010_row13_col0, #T_9e010_row14_col0, #T_9e010_row15_col0, #T_9e010_row19_col0 {
#   background-color: #440154;
#   color: #f1f1f1;
# }
# #T_9e010_row0_col1, #T_9e010_row2_col1, #T_9e010_row5_col1, #T_9e010_row6_col1, #T_9e010_row7_col1, #T_9e010_row8_col1, #T_9e010_row10_col1, #T_9e010_row13_col1, #T_9e010_row14_col1, #T_9e010_row15_col1, #T_9e010_row19_col1 {
#   background-color: #46075a;
#   color: #f1f1f1;
# }
# #T_9e010_row0_col2, #T_9e010_row1_col2, #T_9e010_row7_col2 {
#   background-color: #470e61;
#   color: #f1f1f1;
# }
# #T_9e010_row0_col3, #T_9e010_row17_col2 {
#   background-color: #481b6d;
#   color: #f1f1f1;
# }
# #T_9e010_row0_col4 {
#   background-color: #453581;
#   color: #f1f1f1;
# }
# #T_9e010_row0_col5 {
#   background-color: #3d4e8a;
#   color: #f1f1f1;
# }
# #T_9e010_row0_col6 {
#   background-color: #32648e;
#   color: #f1f1f1;
# }
# #T_9e010_row0_col7, #T_9e010_row8_col7 {
#   background-color: #29798e;
#   color: #f1f1f1;
# }
# #T_9e010_row0_col8 {
#   background-color: #23888e;
#   color: #f1f1f1;
# }
# #T_9e010_row0_col9, #T_9e010_row9_col7 {
#   background-color: #20938c;
#   color: #f1f1f1;
# }
# #T_9e010_row0_col10 {
#   background-color: #1e9b8a;
#   color: #f1f1f1;
# }
# #T_9e010_row1_col1 {
#   background-color: #450559;
#   color: #f1f1f1;
# }
# #T_9e010_row1_col3, #T_9e010_row9_col2, #T_9e010_row19_col2 {
#   background-color: #48186a;
#   color: #f1f1f1;
# }
# #T_9e010_row1_col4, #T_9e010_row17_col3 {
#   background-color: #46327e;
#   color: #f1f1f1;
# }
# #T_9e010_row1_col5, #T_9e010_row16_col4 {
#   background-color: #3e4a89;
#   color: #f1f1f1;
# }
# #T_9e010_row1_col6, #T_9e010_row20_col4 {
#   background-color: #34618d;
#   color: #f1f1f1;
# }
# #T_9e010_row1_col7 {
#   background-color: #2a768e;
#   color: #f1f1f1;
# }
# #T_9e010_row1_col8 {
#   background-color: #24878e;
#   color: #f1f1f1;
# }
# #T_9e010_row1_col9, #T_9e010_row1_col10, #T_9e010_row3_col0, #T_9e010_row3_col1, #T_9e010_row3_col2, #T_9e010_row3_col3, #T_9e010_row3_col4, #T_9e010_row3_col5, #T_9e010_row3_col8, #T_9e010_row3_col9, #T_9e010_row3_col10, #T_9e010_row4_col8, #T_9e010_row6_col2, #T_9e010_row6_col5, #T_9e010_row6_col8, #T_9e010_row7_col9, #T_9e010_row7_col10, #T_9e010_row8_col2, #T_9e010_row8_col5, #T_9e010_row8_col8, #T_9e010_row8_col9, #T_9e010_row8_col10, #T_9e010_row11_col0, #T_9e010_row11_col1, #T_9e010_row11_col2, #T_9e010_row11_col4, #T_9e010_row11_col5, #T_9e010_row11_col6, #T_9e010_row11_col7, #T_9e010_row11_col8, #T_9e010_row11_col9, #T_9e010_row11_col10, #T_9e010_row12_col2, #T_9e010_row12_col5, #T_9e010_row12_col8, #T_9e010_row12_col9, #T_9e010_row12_col10, #T_9e010_row14_col2, #T_9e010_row14_col5, #T_9e010_row14_col8, #T_9e010_row14_col9, #T_9e010_row14_col10, #T_9e010_row15_col9, #T_9e010_row15_col10, #T_9e010_row18_col9, #T_9e010_row18_col10, #T_9e010_row21_col2, #T_9e010_row21_col5, #T_9e010_row21_col8, #T_9e010_row21_col9, #T_9e010_row21_col10, #T_9e010_row23_col10 {
#   background-color: #000000;
#   color: #f1f1f1;
# }
# #T_9e010_row2_col2, #T_9e010_row5_col2 {
#   background-color: #471063;
#   color: #f1f1f1;
# }
# #T_9e010_row2_col3 {
#   background-color: #481d6f;
#   color: #f1f1f1;
# }
# #T_9e010_row2_col4, #T_9e010_row8_col4 {
#   background-color: #443983;
#   color: #f1f1f1;
# }
# #T_9e010_row2_col5 {
#   background-color: #3a548c;
#   color: #f1f1f1;
# }
# #T_9e010_row2_col6, #T_9e010_row5_col6 {
#   background-color: #2e6d8e;
#   color: #f1f1f1;
# }
# #T_9e010_row2_col7, #T_9e010_row14_col7 {
#   background-color: #25848e;
#   color: #f1f1f1;
# }
# #T_9e010_row2_col8 {
#   background-color: #1f948c;
#   color: #f1f1f1;
# }
# #T_9e010_row2_col9, #T_9e010_row10_col9, #T_9e010_row22_col6 {
#   background-color: #1fa188;
#   color: #f1f1f1;
# }
# #T_9e010_row2_col10 {
#   background-color: #25ac82;
#   color: #f1f1f1;
# }
# #T_9e010_row3_col6, #T_9e010_row9_col5 {
#   background-color: #30698e;
#   color: #f1f1f1;
# }
# #T_9e010_row3_col7 {
#   background-color: #27808e;
#   color: #f1f1f1;
# }
# #T_9e010_row4_col0, #T_9e010_row9_col0, #T_9e010_row12_col0, #T_9e010_row17_col0, #T_9e010_row21_col0 {
#   background-color: #450457;
#   color: #f1f1f1;
# }
# #T_9e010_row4_col1, #T_9e010_row17_col1, #T_9e010_row22_col1, #T_9e010_row23_col1 {
#   background-color: #460a5d;
#   color: #f1f1f1;
# }
# #T_9e010_row4_col2 {
#   background-color: #481467;
#   color: #f1f1f1;
# }
# #T_9e010_row4_col3, #T_9e010_row10_col3 {
#   background-color: #482374;
#   color: #f1f1f1;
# }
# #T_9e010_row4_col4 {
#   background-color: #424186;
#   color: #f1f1f1;
# }
# #T_9e010_row4_col5 {
#   background-color: #355e8d;
#   color: #f1f1f1;
# }
# #T_9e010_row4_col6, #T_9e010_row10_col6, #T_9e010_row15_col6 {
#   background-color: #2b758e;
#   color: #f1f1f1;
# }
# #T_9e010_row4_col7, #T_9e010_row5_col8 {
#   background-color: #218f8d;
#   color: #f1f1f1;
# }
# #T_9e010_row4_col9, #T_9e010_row13_col8 {
#   background-color: #25ab82;
#   color: #f1f1f1;
# }
# #T_9e010_row4_col10 {
#   background-color: #2fb47c;
#   color: #f1f1f1;
# }
# #T_9e010_row5_col3, #T_9e010_row8_col3 {
#   background-color: #482071;
#   color: #f1f1f1;
# }
# #T_9e010_row5_col4, #T_9e010_row7_col4 {
#   background-color: #433d84;
#   color: #f1f1f1;
# }
# #T_9e010_row5_col5, #T_9e010_row22_col4 {
#   background-color: #39568c;
#   color: #f1f1f1;
# }
# #T_9e010_row5_col7, #T_9e010_row22_col5 {
#   background-color: #26818e;
#   color: #f1f1f1;
# }
# #T_9e010_row5_col9 {
#   background-color: #21908d;
#   color: #f1f1f1;
# }
# #T_9e010_row5_col10 {
#   background-color: #1f9e89;
#   color: #f1f1f1;
# }
# #T_9e010_row6_col3 {
#   background-color: #481f70;
#   color: #f1f1f1;
# }
# #T_9e010_row6_col4 {
#   background-color: #433e85;
#   color: #f1f1f1;
# }
# #T_9e010_row6_col6 {
#   background-color: #2c728e;
#   color: #f1f1f1;
# }
# #T_9e010_row6_col7 {
#   background-color: #218e8d;
#   color: #f1f1f1;
# }
# #T_9e010_row6_col9 {
#   background-color: #27ad81;
#   color: #f1f1f1;
# }
# #T_9e010_row6_col10 {
#   background-color: #40bd72;
#   color: #f1f1f1;
# }
# #T_9e010_row7_col3 {
#   background-color: #481c6e;
#   color: #f1f1f1;
# }
# #T_9e010_row7_col5 {
#   background-color: #39558c;
#   color: #f1f1f1;
# }
# #T_9e010_row7_col6 {
#   background-color: #2d708e;
#   color: #f1f1f1;
# }
# #T_9e010_row7_col7, #T_9e010_row20_col5 {
#   background-color: #228b8d;
#   color: #f1f1f1;
# }
# #T_9e010_row7_col8 {
#   background-color: #1f9f88;
#   color: #f1f1f1;
# }
# #T_9e010_row8_col6, #T_9e010_row13_col5 {
#   background-color: #32658e;
#   color: #f1f1f1;
# }
# #T_9e010_row9_col1, #T_9e010_row12_col1, #T_9e010_row20_col1, #T_9e010_row21_col1 {
#   background-color: #460b5e;
#   color: #f1f1f1;
# }
# #T_9e010_row9_col3, #T_9e010_row11_col3, #T_9e010_row19_col3, #T_9e010_row22_col3 {
#   background-color: #472a7a;
#   color: #f1f1f1;
# }
# #T_9e010_row9_col4 {
#   background-color: #3e4c8a;
#   color: #f1f1f1;
# }
# #T_9e010_row9_col6, #T_9e010_row13_col6, #T_9e010_row17_col5 {
#   background-color: #277e8e;
#   color: #f1f1f1;
# }
# #T_9e010_row9_col8 {
#   background-color: #20a386;
#   color: #f1f1f1;
# }
# #T_9e010_row9_col9 {
#   background-color: #28ae80;
#   color: #f1f1f1;
# }
# #T_9e010_row9_col10, #T_9e010_row17_col7, #T_9e010_row23_col6 {
#   background-color: #31b57b;
#   color: #f1f1f1;
# }
# #T_9e010_row10_col2, #T_9e010_row13_col2 {
#   background-color: #471164;
#   color: #f1f1f1;
# }
# #T_9e010_row10_col4, #T_9e010_row15_col4 {
#   background-color: #414487;
#   color: #f1f1f1;
# }
# #T_9e010_row10_col5, #T_9e010_row15_col5 {
#   background-color: #355f8d;
#   color: #f1f1f1;
# }
# #T_9e010_row10_col7 {
#   background-color: #238a8d;
#   color: #f1f1f1;
# }
# #T_9e010_row10_col8 {
#   background-color: #1e9c89;
#   color: #f1f1f1;
# }
# #T_9e010_row10_col10, #T_9e010_row20_col6 {
#   background-color: #2ab07f;
#   color: #f1f1f1;
# }
# #T_9e010_row12_col3 {
#   background-color: #482677;
#   color: #f1f1f1;
# }
# #T_9e010_row12_col4, #T_9e010_row13_col4 {
#   background-color: #3f4788;
#   color: #f1f1f1;
# }
# #T_9e010_row12_col6 {
#   background-color: #2a778e;
#   color: #f1f1f1;
# }
# #T_9e010_row12_col7, #T_9e010_row15_col7 {
#   background-color: #228d8d;
#   color: #f1f1f1;
# }
# #T_9e010_row13_col3, #T_9e010_row15_col3 {
#   background-color: #482475;
#   color: #f1f1f1;
# }
# #T_9e010_row13_col7 {
#   background-color: #1f978b;
#   color: #f1f1f1;
# <font color='green'>'imagenet1k'</font> acc1 results for models pre-trained on <font color='red'>'relaion2b-en'</font>  using scheduler <font color='blue'>'cosine'</font>:
# <style type="text/css">
# #T_69a87_row0_col0, #T_69a87_row1_col0, #T_69a87_row3_col0, #T_69a87_row4_col0, #T_69a87_row6_col0, #T_69a87_row7_col0, #T_69a87_row12_col0, #T_69a87_row13_col0 {
#   background-color: #440154;
#   color: #f1f1f1;
# }
# #T_69a87_row0_col1, #T_69a87_row1_col1, #T_69a87_row3_col1, #T_69a87_row4_col1, #T_69a87_row6_col1, #T_69a87_row12_col1 {
#   background-color: #46085c;
#   color: #f1f1f1;
# }
# #T_69a87_row0_col2, #T_69a87_row1_col2, #T_69a87_row3_col2 {
#   background-color: #481467;
#   color: #f1f1f1;
# }
# #T_69a87_row0_col3 {
#   background-color: #482475;
#   color: #f1f1f1;
# }
# #T_69a87_row0_col4 {
#   background-color: #414487;
#   color: #f1f1f1;
# }
# #T_69a87_row0_col5 {
#   background-color: #355f8d;
#   color: #f1f1f1;
# }
# #T_69a87_row0_col6 {
#   background-color: #2a788e;
#   color: #f1f1f1;
# }
# #T_69a87_row0_col7 {
#   background-color: #20928c;
#   color: #f1f1f1;
# }
# #T_69a87_row0_col8 {
#   background-color: #20a386;
#   color: #f1f1f1;
# }
# #T_69a87_row0_col9 {
#   background-color: #2eb37c;
#   color: #f1f1f1;
# }
# #T_69a87_row0_col10, #T_69a87_row7_col8 {
#   background-color: #42be71;
#   color: #f1f1f1;
# }
# #T_69a87_row1_col3, #T_69a87_row3_col3 {
#   background-color: #482677;
#   color: #f1f1f1;
# }
# #T_69a87_row1_col4 {
#   background-color: #3f4889;
#   color: #f1f1f1;
# }
# #T_69a87_row1_col5, #T_69a87_row12_col4 {
#   background-color: #32658e;
#   color: #f1f1f1;
# }
# #T_69a87_row1_col6 {
#   background-color: #27808e;
#   color: #f1f1f1;
# }
# #T_69a87_row1_col7 {
#   background-color: #1f9e89;
#   color: #f1f1f1;
# }
# #T_69a87_row1_col8 {
#   background-color: #2cb17e;
#   color: #f1f1f1;
# }
# #T_69a87_row1_col9, #T_69a87_row8_col7 {
#   background-color: #3dbc74;
#   color: #f1f1f1;
# }
# #T_69a87_row1_col10, #T_69a87_row2_col9, #T_69a87_row2_col10, #T_69a87_row8_col1, #T_69a87_row8_col2, #T_69a87_row8_col3, #T_69a87_row8_col4, #T_69a87_row8_col5, #T_69a87_row8_col9, #T_69a87_row8_col10, #T_69a87_row9_col0, #T_69a87_row9_col1, #T_69a87_row9_col2, #T_69a87_row9_col3, #T_69a87_row9_col4, #T_69a87_row9_col5, #T_69a87_row9_col9, #T_69a87_row9_col10, #T_69a87_row10_col10, #T_69a87_row11_col3, #T_69a87_row12_col9, #T_69a87_row12_col10, #T_69a87_row13_col8, #T_69a87_row13_col9, #T_69a87_row13_col10 {
#   background-color: #000000;
#   color: #f1f1f1;
# }
# #T_69a87_row2_col0, #T_69a87_row8_col0, #T_69a87_row10_col0, #T_69a87_row11_col0 {
#   background-color: #440256;
#   color: #f1f1f1;
# }
# #T_69a87_row2_col1, #T_69a87_row13_col1 {
#   background-color: #470d60;
#   color: #f1f1f1;
# }
# #T_69a87_row2_col2 {
#   background-color: #481b6d;
#   color: #f1f1f1;
# }
# #T_69a87_row2_col3 {
#   background-color: #472f7d;
#   color: #f1f1f1;
# }
# #T_69a87_row2_col4 {
#   background-color: #3b528b;
#   color: #f1f1f1;
# }
# #T_69a87_row2_col5 {
#   background-color: #2d708e;
#   color: #f1f1f1;
# }
# #T_69a87_row2_col6 {
#   background-color: #23888e;
#   color: #f1f1f1;
# }
# #T_69a87_row2_col7 {
#   background-color: #21a585;
#   color: #f1f1f1;
# }
# #T_69a87_row2_col8, #T_69a87_row5_col8, #T_69a87_row11_col6 {
#   background-color: #38b977;
#   color: #f1f1f1;
# }
# #T_69a87_row3_col4 {
#   background-color: #3f4788;
#   color: #f1f1f1;
# }
# #T_69a87_row3_col5 {
#   background-color: #32648e;
#   color: #f1f1f1;
# }
# #T_69a87_row3_col6 {
#   background-color: #287c8e;
#   color: #f1f1f1;
# }
# #T_69a87_row3_col7 {
#   background-color: #20938c;
#   color: #f1f1f1;
# }
# #T_69a87_row3_col8 {
#   background-color: #20a486;
#   color: #f1f1f1;
# }
# #T_69a87_row3_col9, #T_69a87_row7_col7, #T_69a87_row10_col6 {
#   background-color: #25ac82;
#   color: #f1f1f1;
# }
# #T_69a87_row3_col10 {
#   background-color: #32b67a;
#   color: #f1f1f1;
# }
# #T_69a87_row4_col2 {
#   background-color: #481668;
#   color: #f1f1f1;
# }
# #T_69a87_row4_col3 {
#   background-color: #482979;
#   color: #f1f1f1;
# }
# #T_69a87_row4_col4 {
#   background-color: #3d4d8a;
#   color: #f1f1f1;
# }
# #T_69a87_row4_col5, #T_69a87_row13_col4 {
#   background-color: #2f6b8e;
#   color: #f1f1f1;
# }
# #T_69a87_row4_col6 {
#   background-color: #24868e;
#   color: #f1f1f1;
# }
# #T_69a87_row4_col7 {
#   background-color: #21a685;
#   color: #f1f1f1;
# }
# #T_69a87_row4_col8, #T_69a87_row13_col6 {
#   background-color: #3fbc73;
#   color: #f1f1f1;
# }
# #T_69a87_row4_col9, #T_69a87_row6_col10 {
#   background-color: #60ca60;
#   color: #000000;
# }
# #T_69a87_row4_col10 {
#   background-color: #86d549;
#   color: #000000;
# }
# #T_69a87_row5_col0 {
#   background-color: #450457;
#   color: #f1f1f1;
# }
# #T_69a87_row5_col1, #T_69a87_row10_col1, #T_69a87_row11_col1 {
#   background-color: #470e61;
#   color: #f1f1f1;
# }
# #T_69a87_row5_col2 {
#   background-color: #481c6e;
#   color: #f1f1f1;
# }
# #T_69a87_row5_col3 {
#   background-color: #463480;
#   color: #f1f1f1;
# }
# #T_69a87_row5_col4 {
#   background-color: #38588c;
#   color: #f1f1f1;
# }
# #T_69a87_row5_col5 {
#   background-color: #2b758e;
#   color: #f1f1f1;
# }
# #T_69a87_row5_col6 {
#   background-color: #218f8d;
#   color: #f1f1f1;
# }
# #T_69a87_row5_col7 {
#   background-color: #22a884;
#   color: #f1f1f1;
# }
# #T_69a87_row5_col9 {
#   background-color: #50c46a;
#   color: #000000;
# }
# #T_69a87_row5_col10 {
#   background-color: #6ece58;
#   color: #000000;
# }
# #T_69a87_row6_col2, #T_69a87_row7_col2 {
#   background-color: #481769;
#   color: #f1f1f1;
# }
# #T_69a87_row6_col3 {
#   background-color: #472c7a;
#   color: #f1f1f1;
# }
# #T_69a87_row6_col4 {
#   background-color: #3d4e8a;
#   color: #f1f1f1;
# }
# #T_69a87_row6_col5 {
#   background-color: #306a8e;
#   color: #f1f1f1;
# }
# #T_69a87_row6_col6 {
#   background-color: #25858e;
#   color: #f1f1f1;
# }
# #T_69a87_row6_col7 {
#   background-color: #1fa188;
#   color: #f1f1f1;
# }
# #T_69a87_row6_col8 {
#   background-color: #2fb47c;
#   color: #f1f1f1;
# }
# #T_69a87_row6_col9 {
#   background-color: #46c06f;
#   color: #f1f1f1;
# }
# #T_69a87_row7_col1 {
#   background-color: #460a5d;
#   color: #f1f1f1;
# }
# #T_69a87_row7_col3 {
#   background-color: #472d7b;
#   color: #f1f1f1;
# }
# #T_69a87_row7_col4 {
#   background-color: #3a538b;
#   color: #f1f1f1;
# }
# #T_69a87_row7_col5 {
#   background-color: #2c718e;
#   color: #f1f1f1;
# }
# #T_69a87_row7_col6 {
#   background-color: #228d8d;
#   color: #f1f1f1;
# }
# #T_69a87_row7_col9 {
#   background-color: #63cb5f;
#   color: #000000;
# }
# #T_69a87_row7_col10, #T_69a87_row9_col8 {
#   background-color: #89d548;
#   color: #000000;
# }
# #T_69a87_row8_col6 {
#   background-color: #1e9d89;
#   color: #f1f1f1;
# }
# #T_69a87_row8_col8, #T_69a87_row12_col7 {
#   background-color: #70cf57;
#   color: #000000;
# }
# #T_69a87_row9_col6 {
#   background-color: #23a983;
#   color: #f1f1f1;
# }
# #T_69a87_row9_col7 {
#   background-color: #54c568;
#   color: #000000;
# }
# #T_69a87_row10_col2 {
#   background-color: #481f70;
#   color: #f1f1f1;
# }
# #T_69a87_row10_col3, #T_69a87_row13_col3 {
#   background-color: #443a83;
#   color: #f1f1f1;
# }
# #T_69a87_row10_col4 {
#   background-color: #31688e;
#   color: #f1f1f1;
# }
# #T_69a87_row10_col5 {
#   background-color: #23898e;
#   color: #f1f1f1;
# }
# #T_69a87_row10_col7 {
#   background-color: #65cb5e;
#   color: #000000;
# }
# #T_69a87_row10_col8 {
#   background-color: #a2da37;
#   color: #000000;
# }
# #T_69a87_row10_col9 {
#   background-color: #cde11d;
#   color: #000000;
# }
# #T_69a87_row11_col2 {
# ...
#   background-color: #000000;
#   color: #f1f1f1;
# }
# #T_5c1b9_row0_col3, #T_5c1b9_row5_col3, #T_5c1b9_row9_col3 {
#   background-color: #440154;
#   color: #f1f1f1;
# }
# #T_5c1b9_row0_col4 {
#   background-color: #46085c;
#   color: #f1f1f1;
# }
# #T_5c1b9_row0_col5, #T_5c1b9_row18_col0 {
#   background-color: #481668;
#   color: #f1f1f1;
# }
# #T_5c1b9_row0_col6 {
#   background-color: #424186;
#   color: #f1f1f1;
# }
# #T_5c1b9_row0_col7, #T_5c1b9_row8_col5 {
#   background-color: #287d8e;
#   color: #f1f1f1;
# }
# #T_5c1b9_row0_col8, #T_5c1b9_row1_col7, #T_5c1b9_row18_col6 {
#   background-color: #1f958b;
#   color: #f1f1f1;
# }
# #T_5c1b9_row0_col9, #T_5c1b9_row6_col8, #T_5c1b9_row8_col7 {
#   background-color: #21a585;
#   color: #f1f1f1;
# }
# #T_5c1b9_row0_col10, #T_5c1b9_row3_col8 {
#   background-color: #25ac82;
#   color: #f1f1f1;
# }
# #T_5c1b9_row1_col0, #T_5c1b9_row4_col0, #T_5c1b9_row9_col5, #T_5c1b9_row12_col0, #T_5c1b9_row13_col4, #T_5c1b9_row16_col4, #T_5c1b9_row19_col4 {
#   background-color: #471063;
#   color: #f1f1f1;
# }
# #T_5c1b9_row1_col1, #T_5c1b9_row6_col1, #T_5c1b9_row7_col5 {
#   background-color: #481b6d;
#   color: #f1f1f1;
# }
# #T_5c1b9_row1_col2, #T_5c1b9_row6_col2, #T_5c1b9_row19_col5 {
#   background-color: #472c7a;
#   color: #f1f1f1;
# }
# #T_5c1b9_row1_col3, #T_5c1b9_row6_col3 {
#   background-color: #463480;
#   color: #f1f1f1;
# }
# #T_5c1b9_row1_col4, #T_5c1b9_row5_col6 {
#   background-color: #3a548c;
#   color: #f1f1f1;
# }
# #T_5c1b9_row1_col5 {
#   background-color: #2d708e;
#   color: #f1f1f1;
# }
# #T_5c1b9_row1_col6 {
#   background-color: #24868e;
#   color: #f1f1f1;
# }
# #T_5c1b9_row1_col8, #T_5c1b9_row4_col7 {
#   background-color: #1f9e89;
#   color: #f1f1f1;
# }
# #T_5c1b9_row1_col9 {
#   background-color: #2ab07f;
#   color: #f1f1f1;
# }
# #T_5c1b9_row1_col10 {
#   background-color: #35b779;
#   color: #f1f1f1;
# }
# #T_5c1b9_row2_col3, #T_5c1b9_row3_col3, #T_5c1b9_row7_col3, #T_5c1b9_row9_col4, #T_5c1b9_row11_col3, #T_5c1b9_row13_col3, #T_5c1b9_row16_col3, #T_5c1b9_row17_col3, #T_5c1b9_row20_col3, #T_5c1b9_row21_col3, #T_5c1b9_row22_col3, #T_5c1b9_row23_col3 {
#   background-color: #440256;
#   color: #f1f1f1;
# }
# #T_5c1b9_row2_col4, #T_5c1b9_row6_col4, #T_5c1b9_row11_col4 {
#   background-color: #460b5e;
#   color: #f1f1f1;
# }
# #T_5c1b9_row2_col5, #T_5c1b9_row3_col5, #T_5c1b9_row4_col1, #T_5c1b9_row12_col1, #T_5c1b9_row14_col1 {
#   background-color: #481c6e;
#   color: #f1f1f1;
# }
# #T_5c1b9_row2_col6 {
#   background-color: #3a538b;
#   color: #f1f1f1;
# }
# #T_5c1b9_row2_col7, #T_5c1b9_row3_col7, #T_5c1b9_row15_col5 {
#   background-color: #20928c;
#   color: #f1f1f1;
# }
# #T_5c1b9_row2_col8, #T_5c1b9_row10_col7 {
#   background-color: #23a983;
#   color: #f1f1f1;
# }
# #T_5c1b9_row2_col9, #T_5c1b9_row12_col9, #T_5c1b9_row15_col7 {
#   background-color: #3aba76;
#   color: #f1f1f1;
# }
# #T_5c1b9_row2_col10, #T_5c1b9_row10_col9 {
#   background-color: #48c16e;
#   color: #f1f1f1;
# }
# #T_5c1b9_row3_col4, #T_5c1b9_row5_col4, #T_5c1b9_row7_col4, #T_5c1b9_row21_col4, #T_5c1b9_row22_col4 {
#   background-color: #470d60;
#   color: #f1f1f1;
# }
# #T_5c1b9_row3_col6 {
#   background-color: #3d4e8a;
#   color: #f1f1f1;
# }
# #T_5c1b9_row3_col9 {
#   background-color: #3fbc73;
#   color: #f1f1f1;
# }
# #T_5c1b9_row3_col10 {
#   background-color: #4cc26c;
#   color: #000000;
# }
# #T_5c1b9_row4_col2, #T_5c1b9_row12_col2, #T_5c1b9_row18_col5 {
#   background-color: #472e7c;
#   color: #f1f1f1;
# }
# #T_5c1b9_row4_col3 {
#   background-color: #453781;
#   color: #f1f1f1;
# }
# #T_5c1b9_row4_col4 {
#   background-color: #38598c;
#   color: #f1f1f1;
# }
# #T_5c1b9_row4_col5, #T_5c1b9_row14_col6 {
#   background-color: #29798e;
#   color: #f1f1f1;
# }
# #T_5c1b9_row4_col6 {
#   background-color: #218e8d;
#   color: #f1f1f1;
# }
# #T_5c1b9_row4_col8 {
#   background-color: #28ae80;
#   color: #f1f1f1;
# }
# #T_5c1b9_row4_col9 {
#   background-color: #44bf70;
#   color: #f1f1f1;
# }
# #T_5c1b9_row4_col10 {
#   background-color: #56c667;
#   color: #000000;
# }
# #T_5c1b9_row5_col5, #T_5c1b9_row6_col5, #T_5c1b9_row8_col1 {
#   background-color: #481d6f;
#   color: #f1f1f1;
# }
# #T_5c1b9_row5_col7 {
#   background-color: #1f9a8a;
#   color: #f1f1f1;
# }
# #T_5c1b9_row5_col8 {
#   background-color: #31b57b;
#   color: #f1f1f1;
# }
# #T_5c1b9_row5_col9, #T_5c1b9_row7_col9 {
#   background-color: #54c568;
#   color: #000000;
# }
# #T_5c1b9_row5_col10 {
#   background-color: #69cd5b;
#   color: #000000;
# }
# #T_5c1b9_row6_col0, #T_5c1b9_row10_col4, #T_5c1b9_row14_col0, #T_5c1b9_row18_col4, #T_5c1b9_row20_col4, #T_5c1b9_row23_col4 {
#   background-color: #470e61;
#   color: #f1f1f1;
# }
# #T_5c1b9_row6_col6 {
#   background-color: #33638d;
#   color: #f1f1f1;
# }
# #T_5c1b9_row6_col7 {
#   background-color: #20938c;
#   color: #f1f1f1;
# }
# #T_5c1b9_row6_col9 {
#   background-color: #25ab82;
#   color: #f1f1f1;
# }
# #T_5c1b9_row7_col6 {
#   background-color: #3b518b;
#   color: #f1f1f1;
# }
# #T_5c1b9_row7_col7 {
#   background-color: #1f988b;
#   color: #f1f1f1;
# }
# #T_5c1b9_row7_col8 {
#   background-color: #34b679;
#   color: #f1f1f1;
# }
# #T_5c1b9_row7_col10 {
#   background-color: #6ccd5a;
#   color: #000000;
# }
# #T_5c1b9_row8_col0 {
#   background-color: #471164;
#   color: #f1f1f1;
# }
# #T_5c1b9_row8_col2 {
#   background-color: #472f7d;
#   color: #f1f1f1;
# }
# #T_5c1b9_row8_col3, #T_5c1b9_row12_col3 {
#   background-color: #443983;
#   color: #f1f1f1;
# }
# #T_5c1b9_row8_col4, #T_5c1b9_row11_col6 {
#   background-color: #33628d;
#   color: #f1f1f1;
# }
# #T_5c1b9_row8_col6 {
#   background-color: #1f968b;
#   color: #f1f1f1;
# }
# #T_5c1b9_row8_col8, #T_5c1b9_row9_col8 {
#   background-color: #3dbc74;
#   color: #f1f1f1;
# }
# #T_5c1b9_row8_col9, #T_5c1b9_row14_col10 {
#   background-color: #63cb5f;
#   color: #000000;
# }
# #T_5c1b9_row8_col10 {
#   background-color: #75d054;
#   color: #000000;
# }
# #T_5c1b9_row9_col6 {
#   background-color: #453581;
#   color: #f1f1f1;
# }
# #T_5c1b9_row9_col7, #T_5c1b9_row23_col6 {
#   background-color: #228c8d;
#   color: #f1f1f1;
# }
# #T_5c1b9_row9_col9, #T_5c1b9_row15_col8 {
#   background-color: #6ece58;
#   color: #000000;
# }
# #T_5c1b9_row9_col10 {
#   background-color: #81d34d;
#   color: #000000;
# }
# #T_5c1b9_row10_col3, #T_5c1b9_row19_col3 {
#   background-color: #450457;
#   color: #f1f1f1;
# }
# #T_5c1b9_row10_col5, #T_5c1b9_row17_col5 {
#   background-color: #482576;
#   color: #f1f1f1;
# }
# #T_5c1b9_row10_col6 {
#   background-color: #2e6e8e;
#   color: #f1f1f1;
# }
# #T_5c1b9_row10_col8 {
#   background-color: #40bd72;
#   color: #f1f1f1;
# }
# #T_5c1b9_row11_col5, #T_5c1b9_row14_col5 {
#   background-color: #482071;
#   color: #f1f1f1;
# }
# #T_5c1b9_row11_col7 {
#   background-color: #21a685;
#   color: #f1f1f1;
# }
# #T_5c1b9_row11_col8 {
#   background-color: #4ec36b;
#   color: #000000;
# }
# #T_5c1b9_row11_col9 {
#   background-color: #77d153;
#   color: #000000;
# }
# #T_5c1b9_row11_col10 {
#   background-color: #8bd646;
#   color: #000000;
# }
# #T_5c1b9_row12_col4, #T_5c1b9_row17_col4 {
#   background-color: #460a5d;
#   color: #f1f1f1;
# }
# #T_5c1b9_row12_col5, #T_5c1b9_row21_col5 {
#   background-color: #482475;
#   color: #f1f1f1;
# }
# #T_5c1b9_row12_col6 {
#   backgroun
# <font color='green'>'mscoco_captions'</font> text_retrieval_recall@5 results for models pre-trained on <font color='red'>'datacomp_1b'</font>  using scheduler <font color='blue'>'const'</font>:
# <style type="text/css">
# #T_bfc50_row0_col0, #T_bfc50_row0_col1, #T_bfc50_row0_col2, #T_bfc50_row2_col0, #T_bfc50_row2_col1, #T_bfc50_row2_col2, #T_bfc50_row3_col0, #T_bfc50_row3_col1, #T_bfc50_row3_col2, #T_bfc50_row5_col0, #T_bfc50_row5_col1, #T_bfc50_row5_col2, #T_bfc50_row6_col10, #T_bfc50_row7_col0, #T_bfc50_row7_col1, #T_bfc50_row7_col2, #T_bfc50_row9_col0, #T_bfc50_row9_col1, #T_bfc50_row9_col2, #T_bfc50_row10_col0, #T_bfc50_row10_col1, #T_bfc50_row10_col2, #T_bfc50_row10_col10, #T_bfc50_row11_col0, #T_bfc50_row11_col1, #T_bfc50_row11_col2, #T_bfc50_row12_col10, #T_bfc50_row13_col0, #T_bfc50_row13_col1, #T_bfc50_row13_col2, #T_bfc50_row14_col4, #T_bfc50_row16_col0, #T_bfc50_row16_col1, #T_bfc50_row16_col2, #T_bfc50_row17_col0, #T_bfc50_row17_col1, #T_bfc50_row17_col2, #T_bfc50_row17_col10, #T_bfc50_row18_col10, #T_bfc50_row19_col0, #T_bfc50_row19_col1, #T_bfc50_row19_col2, #T_bfc50_row20_col0, #T_bfc50_row20_col1, #T_bfc50_row20_col2, #T_bfc50_row20_col10, #T_bfc50_row21_col0, #T_bfc50_row21_col1, #T_bfc50_row21_col2, #T_bfc50_row22_col0, #T_bfc50_row22_col1, #T_bfc50_row22_col2, #T_bfc50_row22_col9, #T_bfc50_row22_col10, #T_bfc50_row23_col0, #T_bfc50_row23_col1, #T_bfc50_row23_col2, #T_bfc50_row23_col9, #T_bfc50_row23_col10 {
#   background-color: #000000;
#   color: #f1f1f1;
# }
# #T_bfc50_row0_col3, #T_bfc50_row2_col3, #T_bfc50_row3_col3, #T_bfc50_row5_col3, #T_bfc50_row7_col3, #T_bfc50_row11_col3, #T_bfc50_row13_col3, #T_bfc50_row16_col3, #T_bfc50_row17_col3, #T_bfc50_row21_col3, #T_bfc50_row22_col3 {
#   background-color: #440256;
#   color: #f1f1f1;
# }
# #T_bfc50_row0_col4, #T_bfc50_row2_col4, #T_bfc50_row3_col4, #T_bfc50_row6_col4, #T_bfc50_row11_col4, #T_bfc50_row12_col4, #T_bfc50_row21_col4, #T_bfc50_row22_col4 {
#   background-color: #470d60;
#   color: #f1f1f1;
# }
# #T_bfc50_row0_col5 {
#   background-color: #481a6c;
#   color: #f1f1f1;
# }
# #T_bfc50_row0_col6 {
#   background-color: #3d4e8a;
#   color: #f1f1f1;
# }
# #T_bfc50_row0_col7 {
#   background-color: #20938c;
#   color: #f1f1f1;
# }
# #T_bfc50_row0_col8, #T_bfc50_row8_col6 {
#   background-color: #25ac82;
#   color: #f1f1f1;
# }
# #T_bfc50_row0_col9, #T_bfc50_row6_col8 {
#   background-color: #3aba76;
#   color: #f1f1f1;
# }
# #T_bfc50_row0_col10, #T_bfc50_row3_col8, #T_bfc50_row14_col7 {
#   background-color: #48c16e;
#   color: #f1f1f1;
# }
# #T_bfc50_row1_col0, #T_bfc50_row4_col0, #T_bfc50_row9_col5 {
#   background-color: #481467;
#   color: #f1f1f1;
# }
# #T_bfc50_row1_col1, #T_bfc50_row3_col5, #T_bfc50_row4_col1, #T_bfc50_row6_col5, #T_bfc50_row8_col1 {
#   background-color: #482374;
#   color: #f1f1f1;
# }
# #T_bfc50_row1_col2, #T_bfc50_row18_col1 {
#   background-color: #463480;
#   color: #f1f1f1;
# }
# #T_bfc50_row1_col3, #T_bfc50_row6_col3 {
#   background-color: #424086;
#   color: #f1f1f1;
# }
# #T_bfc50_row1_col4 {
#   background-color: #32648e;
#   color: #f1f1f1;
# }
# #T_bfc50_row1_col5, #T_bfc50_row10_col6, #T_bfc50_row15_col4 {
#   background-color: #25848e;
#   color: #f1f1f1;
# }
# #T_bfc50_row1_col6 {
#   background-color: #1f9a8a;
#   color: #f1f1f1;
# }
# #T_bfc50_row1_col7, #T_bfc50_row6_col7 {
#   background-color: #23a983;
#   color: #f1f1f1;
# }
# #T_bfc50_row1_col8, #T_bfc50_row5_col7 {
#   background-color: #31b57b;
#   color: #f1f1f1;
# }
# #T_bfc50_row1_col9 {
#   background-color: #54c568;
#   color: #000000;
# }
# #T_bfc50_row1_col10, #T_bfc50_row3_col9, #T_bfc50_row12_col9 {
#   background-color: #63cb5f;
#   color: #000000;
# }
# #T_bfc50_row2_col5, #T_bfc50_row6_col1, #T_bfc50_row7_col5, #T_bfc50_row12_col1, #T_bfc50_row14_col1 {
#   background-color: #482173;
#   color: #f1f1f1;
# }
# #T_bfc50_row2_col6 {
#   background-color: #34618d;
#   color: #f1f1f1;
# }
# #T_bfc50_row2_col7, #T_bfc50_row9_col7 {
#   background-color: #20a386;
#   color: #f1f1f1;
# }
# #T_bfc50_row2_col8 {
#   background-color: #3fbc73;
#   color: #f1f1f1;
# }
# #T_bfc50_row2_col9 {
#   background-color: #69cd5b;
#   color: #000000;
# }
# #T_bfc50_row2_col10 {
#   background-color: #7ad151;
#   color: #000000;
# }
# #T_bfc50_row3_col6 {
#   background-color: #34608d;
#   color: #f1f1f1;
# }
# #T_bfc50_row3_col7 {
#   background-color: #22a884;
#   color: #f1f1f1;
# }
# #T_bfc50_row3_col10, #T_bfc50_row4_col9 {
#   background-color: #75d054;
#   color: #000000;
# }
# #T_bfc50_row4_col2, #T_bfc50_row8_col2 {
#   background-color: #443a83;
#   color: #f1f1f1;
# }
# #T_bfc50_row4_col3 {
#   background-color: #404588;
#   color: #f1f1f1;
# }
# #T_bfc50_row4_col4 {
#   background-color: #30698e;
#   color: #f1f1f1;
# }
# #T_bfc50_row4_col5 {
#   background-color: #228d8d;
#   color: #f1f1f1;
# }
# #T_bfc50_row4_col6 {
#   background-color: #21a585;
#   color: #f1f1f1;
# }
# #T_bfc50_row4_col7, #T_bfc50_row7_col7, #T_bfc50_row20_col6 {
#   background-color: #2db27d;
#   color: #f1f1f1;
# }
# #T_bfc50_row4_col8 {
#   background-color: #50c46a;
#   color: #000000;
# }
# #T_bfc50_row4_col10, #T_bfc50_row17_col7 {
#   background-color: #84d44b;
#   color: #000000;
# }
# #T_bfc50_row5_col4, #T_bfc50_row7_col4, #T_bfc50_row18_col4, #T_bfc50_row23_col4 {
#   background-color: #471063;
#   color: #f1f1f1;
# }
# #T_bfc50_row5_col5 {
#   background-color: #482475;
#   color: #f1f1f1;
# }
# #T_bfc50_row5_col6, #T_bfc50_row7_col6, #T_bfc50_row18_col3 {
#   background-color: #33628d;
#   color: #f1f1f1;
# }
# #T_bfc50_row5_col8 {
#   background-color: #5ac864;
#   color: #000000;
# }
# #T_bfc50_row5_col9, #T_bfc50_row13_col8 {
#   background-color: #7fd34e;
#   color: #000000;
# }
# #T_bfc50_row5_col10 {
#   background-color: #90d743;
#   color: #000000;
# }
# #T_bfc50_row6_col0, #T_bfc50_row8_col0, #T_bfc50_row13_col4, #T_bfc50_row14_col0 {
#   background-color: #471365;
#   color: #f1f1f1;
# }
# #T_bfc50_row6_col2 {
#   background-color: #453581;
#   color: #f1f1f1;
# }
# #T_bfc50_row6_col6 {
#   background-color: #2c718e;
#   color: #f1f1f1;
# }
# #T_bfc50_row6_col9 {
#   background-color: #46c06f;
#   color: #f1f1f1;
# }
# #T_bfc50_row7_col8, #T_bfc50_row12_col8 {
#   background-color: #5ec962;
#   color: #000000;
# }
# #T_bfc50_row7_col9, #T_bfc50_row14_col9 {
#   background-color: #86d549;
#   color: #000000;
# }
# #T_bfc50_row7_col10, #T_bfc50_row15_col8 {
#   background-color: #95d840;
#   color: #000000;
# }
# #T_bfc50_row8_col3 {
#   background-color: #404688;
#   color: #f1f1f1;
# }
# #T_bfc50_row8_col4 {
#   background-color: #2d718e;
#   color: #f1f1f1;
# }
# #T_bfc50_row8_col5 {
#   background-color: #20928c;
#   color: #f1f1f1;
# }
# #T_bfc50_row8_col7 {
#   background-color: #38b977;
#   color: #f1f1f1;
# }
# #T_bfc50_row8_col8, #T_bfc50_row16_col7 {
#   background-color: #65cb5e;
#   color: #000000;
# }
# #T_bfc50_row8_col9 {
#   background-color: #8bd646;
#   color: #000000;
# }
# #T_bfc50_row8_col10, #T_bfc50_row11_col9 {
#   background-color: #a0da39;
#   color: #000000;
# }
# #T_bfc50_row9_col3, #T_bfc50_row9_col4 {
#   background-color: #440154;
#   color: #f1f1f1;
# }
# #T_bfc50_row9_col6 {
#   background-color: #414287;
#   color: #f1f1f1;
# }
# #T_bfc50_row9_col8 {
#   background-color: #6ccd5a;
#   color: #000000;
# }
# #T_bfc50_row9_col9, #T_bfc50_row18_col7, #T_bfc50_row19_col7 {
#   background-color: #93d741;
#   color: #000000;
# }
# #T_bfc50_row9_col10 {
#   background-color: #aadc32;
#   color: #000000;
# }
# #T_bfc50_row10_col3, #T_bfc50_row19_col3, #T_bfc50_row20_col3, #T_bfc50_row23_col3 {
#   background-color: #450457;
#   color: #f1f1f1;
# }
# #T_bfc50_row10_col4, #T_bfc50_row12_col0, #T_bfc50_row16_col4, #T_bfc50_row19_col4 {
#   background-color: #471164;
#   color: #f1f1f1;
# }
# #T_bfc50_row10_col5, #T_bfc50_row16_col5, #T_bfc50_row17_col5, #T_bfc50_row21_col5 {
#   background-color: #472d7b;
#   color: #f1f1f1;
# }
# #T_bfc50_row10_col7, #T_bfc50_row13_col7, #T_bfc50_row15_col6 {
#   background-color: #42be71;
#   color: #f1f1f1;
# }
# #T_bfc50_row10_col8 {
#   background-color: #70cf57;
#   color: #000000;
# }
# #T_bfc50_row10_col9, #T_bfc50_row14_col8 {
#   background-color: #73d056;
#   color: #000000;
# }
# #T_bfc50_row11_col5, #T_bfc50_row22_col5 {
#   background-color: #482878;
#   color: #f1f1f1;
# }
# #T_bfc50_row11_col6 {
#   background-color: #2c738e;
#   color: #f1f1f1;
# }
# #T_bfc50_row11_col7 {
#   background-color: #3bbb75;
#   color: #f1f1f1;
# }
# #T_bfc50_row11_col8 {
#   background-color: #77d153;
#   color: #000000;
# }
# #T_bfc50_row11_col10, #T_bfc50_row15_col9 {
#   background-color: #b5de2b;
#   color: #000000;
# }
# #T_bfc50_row12_col2 {
#   background-color: #453882;
#   color: #f1f1f1;
# }
